# %% [markdown]
# # Importing libraries and dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/hotel_booking_data_cleaned.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              01/07/2015
# 1              01/07/2015
# 2              02/07/2015
# 3              02/07/2015
# 4              03/07/2015
#
# [5 rows x 32 columns]

# %% [markdown]
# # Data Cleaning and Analysis

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(16), object(11)
# memory usage: 29.1+ MB

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %%
df.drop(['company','agent'],axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# reservation_status_date           0
# dtype: int64

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       118898             118898  118898  118898         118898
# unique           2                 12       5     177              7
# top     City Hotel             August      BB     PRT      Online TA
# freq         79302              13852   91863   48586          56402
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                118898             118898             118898
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97730              85601              73863
#
#        deposit_type customer_type reservation_status
# count        118898        118898             118898
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104163         89174              74745

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
#
#        stays_in_weekend_nights  stays_in_week_nights         adults  \
# count            118898.000000         118898.000000  118898.000000
# mean                  0.928897              2.502145       1.858391
# std                   0.996216              1.900168       0.578576
# min                   0.000000              0.000000       0.000000
# 25%                   0.000000              1.000000       2.000000
# 50%                   1.000000              2.000000       2.000000
# 75%                   2.000000              3.000000       2.000000
# max                  16.000000             41.000000      55.000000
#
#             children         babies  is_repeated_guest  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.104207       0.007948           0.032011
# std         0.399172       0.097380           0.176029
# min         0.000000       0.000000           0.000000
# 25%         0.000000       0.000000           0.000000
# 50%         0.000000       0.000000           0.000000
# 75%         0.000000       0.000000           0.000000
# max        10.000000      10.000000           1.000000
#
#        previous_cancellations  previous_bookings_not_canceled  \
# count           118898.000000                   118898.000000
# mean                 0.087142                        0.131634
# std                  0.845869                        1.484672
# min                  0.000000                        0.000000
# 25%                  0.000000                        0.000000
# 50%                  0.000000                        0.000000
# 75%                  0.000000                        0.000000
# max                 26.000000                       72.000000
#
#        booking_changes  days_in_waiting_list            adr  \
# count    118898.000000         118898.000000  118898.000000
# mean          0.221181              2.330754     102.003243
# std           0.652785             17.630452      50.485862
# min           0.000000              0.000000      -6.380000
# 25%           0.000000              0.000000      70.000000
# 50%           0.000000              0.000000      95.000000
# 75%           0.000000              0.000000     126.000000
# max          21.000000            391.000000    5400.000000
#
#        required_car_parking_spaces  total_of_special_requests
# count                118898.000000              118898.000000
# mean                      0.061885                   0.571683
# std                       0.244172                   0.792678
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       0.000000                   0.000000
# 75%                       0.000000                   1.000000
# max                       8.000000                   5.000000

# %% [markdown]
# # Analysis and Findings

# %%
cancellation_percentage = df['is_canceled'].value_counts(normalize=True)
print(cancellation_percentage)
# Out:
# 0    0.628648
# 1    0.371352
# Name: is_canceled, dtype: float64

# %% [markdown]
# In the above results, 0 represents the not-canceled ratio, while 1 represents the cancellation ratio.

# %% [markdown]
# # No-Cancellation Ratio vs Cancellation

# %%
not_cancelled_percentage = cancellation_percentage[0] * 100
cancelled_percentage = cancellation_percentage[1] * 100
print(not_cancelled_percentage)
print(cancelled_percentage)
# Out:
# 62.864808491311884
# 37.13519150868812

# %%
print(f"No-Cancellation Ratio: {not_cancelled_percentage:.2f}%")
print(f"Cancellation Ratio: {cancelled_percentage:.2f}%")
# Out:
# No-Cancellation Ratio: 62.86%
# Cancellation Ratio: 37.14%

# %%
categories = ['No Cancellation Ratio', 'Cancellation Ratio']
cancel_ratio = [not_cancelled_percentage, cancelled_percentage]
colors = ('red','blue')
ax = sns.barplot(x = categories, y = cancel_ratio,palette=colors, width = 0.5)
plt.xlabel('Categories')
plt.ylabel('Percentages')
plt.title('Fig 1: No-Cancellation Ratio vs Cancellation Ratio')
plt.show()
# Out:
# <ipython-input-20-374b684d4e64>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = categories, y = cancel_ratio,palette=colors, width = 0.5)

# %% [markdown]
# # No-Cancellation and Cancellation Ratio in Each Hotel

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.582911
# 1    0.417089
# Name: is_canceled, dtype: float64

# %%
city_hotel_ratio = city_hotel['is_canceled'].value_counts(normalize = True)
print(city_hotel_ratio)
# Out:
# 0    0.582911
# 1    0.417089
# Name: is_canceled, dtype: float64

# %%
city_hotel_cancellation_percentage = city_hotel_ratio[1] * 100
city_hotel_no_cancellation_percentage = city_hotel_ratio[0] * 100
print(city_hotel_cancellation_percentage)
print(city_hotel_no_cancellation_percentage)
# Out:
# 41.70891024186023
# 58.29108975813977

# %%
print(f"City Hotel Cancellation Percentage: {city_hotel_cancellation_percentage: .2f}%")
print(f"City Hotel No-Cancellation Percentage: {city_hotel_no_cancellation_percentage: .2f}%")
# Out:
# City Hotel Cancellation Percentage:  41.71%
# City Hotel No-Cancellation Percentage:  58.29%

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
resort_hotel_ratio = resort_hotel['is_canceled'].value_counts(normalize = True)
print(resort_hotel_ratio)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
resort_hotel_cancellation_percentage = resort_hotel_ratio[0] * 100
resort_hotel_no_cancellation_percentage = resort_hotel_ratio[1] * 100
print(resort_hotel_cancellation_percentage)
print(resort_hotel_no_cancellation_percentage)
# Out:
# 72.02495201535508
# 27.975047984644913

# %%
print(f'Resort Hotel Cancellation Percentag: {resort_hotel_cancellation_percentage: .2f}%')
print(f'Resort Hotel No Cancellation Percentag: {resort_hotel_no_cancellation_percentage: .2f}%')
# Out:
# Resort Hotel Cancellation Percentag:  72.02%
# Resort Hotel No Cancellation Percentag:  27.98%

# %%
ax = sns.countplot(x='hotel', hue='is_canceled', data=df, palette=['red',  'blue'], width=0.7)
ax.legend(labels=['Not Canceled', 'Canceled'], bbox_to_anchor=(1, 1))
plt.title('Fig 2: No-Cancellation and Cancellation Ratio in Each Hotel')
plt.xlabel('Hotels Names')
plt.ylabel('No-Cancellation / Cancellation Counts')
plt.show()

# %% [markdown]
# # City Hotel Cancellation Percentage VS No-Cancellation

# %%
labels = ['Cancellation', 'No-Cancellation']
colors = ['red', 'green']
plt.pie([city_hotel_cancellation_percentage,
         city_hotel_no_cancellation_percentage],
        labels=labels, autopct='%1.2f%%', colors=colors)
plt.title('Fig 3: City Hotel Cancellation Percentage VS No-Cancellation')
plt.show()

# %% [markdown]
# # Resort Hotel Cancellation Percentage VS No-Cancellation

# %%
labels = ['Cancellation', 'No-Cancellation']
colors = ['yellow', 'green']
plt.pie([resort_hotel_cancellation_percentage,
         resort_hotel_no_cancellation_percentage],
        labels=labels, autopct='%1.2f%%', colors=colors)
plt.title('Fig 4: Resort Hotel Cancellation Percentage VS No-Cancellation')
plt.show()

# %% [markdown]
# As we can see, resort hotels are experiencing a higher rate of reservation cancellations compared to city hotels

# %% [markdown]
# # Comparing Prices of Both Hotels

# %%
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean() #adr = average daily rate
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.rc('font', size=18)

plt.figure(figsize=(16, 8))

plt.title('Fig 5: Average Daily Rate in City Hotel and Resort Hotel', fontsize=30, pad=30)
plt.xlabel('Months', labelpad=20)
plt.ylabel('Prices', labelpad=20)

plt.gca().set_facecolor('green')
plt.plot(city_hotel.index, city_hotel['adr'], label = 'City Hotel', color='red')
plt.plot(resort_hotel.index, resort_hotel['adr'], label = 'Resort Hotel', color='yellow')
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# In the above plot, there are spikes. We can consider that, these spikes are on the weekends. On the weekends, the prices of City Hotel and Resort Hotels become high.
#
# It also show that, in comparison to Resort Hotel, City Hotel have more bookings. It is possible that, Resort Hotels are more expensive than those in cities.

# %% [markdown]
# # Cancellation Rate on Monthly Basis

# %%
monthName =df['arrival_date_month'].unique()
print(monthName)
# Out:
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']

# %%
plt.rc('font', size=12)

plt.figure(figsize=(16, 8))
ax = sns.countplot(x=df['arrival_date_month'], hue='is_canceled', data=df, palette=['green', 'red'], width=0.7)
ax.legend(labels=['No-Cancellation', 'Cancellation'])
plt.title('Fig 6: Monthly Reservation Counts', fontsize=20, pad=20)
plt.xlabel('Months', labelpad=20)
plt.ylabel('Reservation Counts', labelpad=20)
ax.set_facecolor("grey")
plt.show()

# %% [markdown]
# Additionally, examining the average daily rate on a monthly basis can provide valuable insights.

# %%
df['month'] = df['reservation_status_date'].dt.month
df['month'].unique()
# Out:
# array([ 7,  5,  4,  6,  3,  8,  9,  1, 11, 10, 12,  2])

# %%
plt.rc('font', size=12)

data = df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index()

plt.figure(figsize=(15, 8))

ax = sns.barplot(x=monthName, y='adr', data=data,
            palette=['red', 'blue', 'green', 'purple', 'yellow', 'skyblue', 'grey'])
plt.title("Fig 7: Monthly Average Daily Rate", fontsize=20, pad=20)
plt.xlabel('Months', labelpad=20)
plt.ylabel('Average Daily Rate', labelpad=20)
ax.set_facecolor("white")
plt.show()
# Out:
# <ipython-input-37-16cd41f56dc8>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=monthName, y='adr', data=data,
# <ipython-input-37-16cd41f56dc8>:7: UserWarning:
# The palette list has fewer values (7) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=monthName, y='adr', data=data,

# %% [markdown]
# # Cancellation Rate on The Basis of Countries (Top 5)

# %%
cancelled_data = df[df['is_canceled'] == 1]
top_5_countries = cancelled_data['country'].value_counts().head(5)
print(top_5_countries)
# Out:
# PRT    27515
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
# Name: country, dtype: int64

# %%
plt.rc('font', size=12)

colors = ['red', 'yellow', 'blue', 'skyblue', 'green']

plt.figure(figsize=(8, 8))
plt.title('Fig 8: Top 5 Countries with High Cancellation Ratio', fontsize=20, pad=20)
plt.pie(top_5_countries, autopct='%1.2f%%', labels=top_5_countries.index, colors=colors,
       startangle=90 )
plt.show()

# %% [markdown]
# # Market Segment Ratio Observation

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24160
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
market_segment_ratio_overall = df['market_segment'].value_counts(normalize=True)*100
market_segment_ratio_overall
# Out:
# Online TA        47.437299
# Offline TA/TO    20.319938
# Groups           16.657976
# Direct           10.469478
# Corporate         4.298643
# Complementary     0.617336
# Aviation          0.199331
# Name: market_segment, dtype: float64

# %%
plt.rc('font', size=12)

colors = ['red', 'blue', 'green', 'purple', 'yellow', 'skyblue', 'orange']

fig, ax = plt.subplots(figsize=(12, 6))

ax.bar(x=df['market_segment'].value_counts().index, height=df['market_segment'].value_counts(), color=colors)

plt.title('Fig 9: Customers Market Segment Ratio', fontsize=20, pad=20)
plt.xlabel('Sources', labelpad=25)
plt.ylabel('Market Segment Ratio (%)', labelpad=25)

ax.set_facecolor("grey")

plt.show()

# %% [markdown]
# As we can see, the majority of clients (47.437%) are coming from online sources. However, we initially asserted that the majority of clients come from offline sources. Hence, our hypothesis was incorrect.

# %% [markdown]
# # Market Segment Ratio vs Cancellation Ratio

# %%
cancelled_data['market_segment'].value_counts()
# Out:
# Online TA        20738
# Groups           12097
# Offline TA/TO     8278
# Direct            1920
# Corporate          978
# Complementary       90
# Aviation            52
# Name: market_segment, dtype: int64

# %%
market_segment_ratio_cancelled = cancelled_data['market_segment'].value_counts(normalize=True)*100
market_segment_ratio_cancelled
# Out:
# Online TA        46.968496
# Groups           27.397912
# Offline TA/TO    18.748443
# Direct            4.348515
# Corporate         2.215025
# Complementary     0.203837
# Aviation          0.117772
# Name: market_segment, dtype: float64

# %%
plt.rc('font', size=12)

plt.figure(figsize=(12, 6))

ax = sns.lineplot(x=market_segment_ratio_cancelled.index, y=market_segment_ratio_cancelled.values, marker='o', color='blue')

plt.title('Fig 10: Cancellation Ratio for Each Market Segment', fontsize=20, pad=20)
plt.xlabel('Market Segment', labelpad=25)
plt.ylabel('Cancellation Ratio (%)', labelpad=25)

ax.set_facecolor("grey")

ax.grid(True)

plt.show()
